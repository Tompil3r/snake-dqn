# %%
from model import build_model
from rl_lib.agents import DQNAgent
from rl_lib.memory import ReplayMemory
from rl_lib.policy import EpsilonGreedyQPolicy, GreedyQPolicy
from rl_lib.epsilon_decay import EpisodicDecay

import gym

# %%
def build_agent(model, target_model, nb_actions):
    memory = ReplayMemory(10000)
    decay = EpisodicDecay()
    policy = EpsilonGreedyQPolicy(eps=0.1)
    test_policy = GreedyQPolicy()
    return DQNAgent(nb_actions, model, memory, policy, test_policy, target_model)

# %%
env = gym.make('CartPole-v0')
nb_actions = env.action_space.n
state_shape = (1, env.observation_space.shape[0])

# %%
model = build_model(state_shape, nb_actions)
model.compile(optimizer='adam', loss='mse', metrics=['mse'])
target_model = build_model(state_shape, nb_actions)
target_model.compile(optimizer='adam', loss='mse', metrics=['mse'])
agent = build_agent(model, target_model, nb_actions)

# %%
agent.warmup(env, 100)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 4), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (None, 4).

# %%
agent.fit(env, 1000)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 4), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (32, 4).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 4), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (32, 4).
# WARNING:tensorflow:Model was constructed with shape (None, 1, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 4), dtype=tf.float32, name='flatten_input'), name='flatten_input', description="created by layer 'flatten_input'"), but it was called on an input with incompatible shape (32, 4).
# 1000/1000 Completed - 100.00%
# {'episode_steps': [10,
#   11,
#   12,
#   11,
#   11,
#   11,
#   12,
#   10,
#   13,
#   10,
#   28,
#   11,
#   13,
#   11,
#   10,
#   104,
#   37,
#   28,
#   33,
#   48,
#   20,
#   47,
#   24,
#   45,
#   28,
#   40,
#   24,
#   35,
#   20,
#   27,
#   29,
#   19,
#   30,
#   35,
#   20,
#   39,
#   17,
#   30,
#   37,
#   32],
#  'episode_rewards': [9.0,
#   10.0,
#   11.0,
#   10.0,
#   10.0,
#   10.0,
#   11.0,
#   9.0,
#   12.0,
#   9.0,
#   27.0,
#   10.0,
#   12.0,
#   10.0,
#   9.0,
#   103.0,
#   36.0,
#   27.0,
#   32.0,
#   47.0,
#   19.0,
#   46.0,
#   23.0,
#   44.0,
#   27.0,
#   39.0,
#   23.0,
#   34.0,
#   19.0,
#   26.0,
#   28.0,
#   18.0,
#   29.0,
#   34.0,
#   19.0,
#   38.0,
#   16.0,
#   29.0,
#   36.0,
#   31.0]}

# %%
agent.test(env, 100, visualize=False)
# Out:
# {'episode_steps': [26,
#   30,
#   33,
#   26,
#   34,
#   29,
#   34,
#   27,
#   35,
#   48,
#   29,
#   29,
#   29,
#   23,
#   28,
#   31,
#   28,
#   30,
#   27,
#   33,
#   29,
#   38,
#   32,
#   31,
#   35,
#   32,
#   23,
#   29,
#   42,
#   28,
#   28,
#   39,
#   33,
#   43,
#   29,
#   39,
#   44,
#   34,
#   33,
#   35,
#   30,
#   25,
#   28,
#   29,
#   31,
#   28,
#   37,
#   24,
#   26,
#   26,
#   29,
#   30,
#   32,
#   39,
#   31,
#   43,
#   35,
#   27,
#   26,
#   31,
#   39,
#   24,
#   25,
#   29,
#   28,
#   26,
#   25,
#   30,
#   20,
#   24,
#   27,
#   27,
#   39,
#   33,
#   33,
#   25,
#   25,
#   34,
#   33,
#   40,
#   35,
#   35,
#   25,
#   20,
#   29,
#   24,
#   40,
#   43,
#   35,
#   32,
#   35,
#   30,
#   36,
#   24,
#   33,
#   24,
#   27,
#   31,
#   28,
#   24],
#  'episode_rewards': [26.0,
#   30.0,
#   33.0,
#   26.0,
#   34.0,
#   29.0,
#   34.0,
#   27.0,
#   35.0,
#   48.0,
#   29.0,
#   29.0,
#   29.0,
#   23.0,
#   28.0,
#   31.0,
#   28.0,
#   30.0,
#   27.0,
#   33.0,
#   29.0,
#   38.0,
#   32.0,
#   31.0,
#   35.0,
#   32.0,
#   23.0,
#   29.0,
#   42.0,
#   28.0,
#   28.0,
#   39.0,
#   33.0,
#   43.0,
#   29.0,
#   39.0,
#   44.0,
#   34.0,
#   33.0,
#   35.0,
#   30.0,
#   25.0,
#   28.0,
#   29.0,
#   31.0,
#   28.0,
#   37.0,
#   24.0,
#   26.0,
#   26.0,
#   29.0,
#   30.0,
#   32.0,
#   39.0,
#   31.0,
#   43.0,
#   35.0,
#   27.0,
#   26.0,
#   31.0,
#   39.0,
#   24.0,
#   25.0,
#   29.0,
#   28.0,
#   26.0,
#   25.0,
#   30.0,
#   20.0,
#   24.0,
#   27.0,
#   27.0,
#   39.0,
#   33.0,
#   33.0,
#   25.0,
#   25.0,
#   34.0,
#   33.0,
#   40.0,
#   35.0,
#   35.0,
#   25.0,
#   20.0,
#   29.0,
#   24.0,
#   40.0,
#   43.0,
#   35.0,
#   32.0,
#   35.0,
#   30.0,
#   36.0,
#   24.0,
#   33.0,
#   24.0,
#   27.0,
#   31.0,
#   28.0,
#   24.0]}

# %%
agent.policy.eps
# Out:
# 0.1

# %%
print(agent.model.layers)
# Out:
# [<tensorflow.python.keras.layers.core.Flatten object at 0x0000028B7F7AED08>, <tensorflow.python.keras.layers.core.Dense object at 0x0000028B7F797C08>, <tensorflow.python.keras.layers.core.Dense object at 0x0000028B7F7CFAC8>, <tensorflow.python.keras.layers.core.Dense object at 0x0000028B7F837088>]

# %%
agent.save_weights('weights.h5')
